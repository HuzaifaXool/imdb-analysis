# %%
import pandas as pd
import numpy as np

# %%
imdb=pd.read_csv('IMDB Movies Data - movie_metadata.csv')

# %%
imdb
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
imdb.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
imdb['profit']=imdb['gross']-imdb['budget']

# %%
imdb['roi']=(imdb['gross']-imdb['budget'])/imdb['budget']

# %%
imdb[['gross','budget','profit','roi']].head()
# Out:
#          gross       budget       profit       roi
# 0  760505847.0  237000000.0  523505847.0  2.208885
# 1  309404152.0  300000000.0    9404152.0  0.031347
# 2  200074175.0  245000000.0  -44925825.0 -0.183371
# 3  448130642.0  250000000.0  198130642.0  0.792523
# 4          NaN          NaN          NaN       NaN

# %% [markdown]
# # 1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
Highest_profit=imdb.loc[imdb['profit'].idxmax()]
director=Highest_profit['director_name']
profit=Highest_profit['profit']
actors=Highest_profit['actor_1_name'],Highest_profit['actor_2_name'],Highest_profit['actor_3_name']
movie_name=Highest_profit['movie_title']
print(f'The Highest Profit is {profit} \nThe movie which made this profit was {movie_name}\nwhich is directed by {director}\nThe cast was {actors}')
# Out:
# The Highest Profit is 523505847.0
# The movie which made this profit was Avatar
# which is directed by James Cameron
# The cast was ('CCH Pounder', 'Joel David Moore', 'Wes Studi')

# %% [markdown]
# # 2. This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
lang_roi= imdb.groupby('language')['roi'].mean()
highest_avg_roi_language=lang_roi.idxmax()
highest_avg_roi_value=lang_roi.max()
print(f'The Highest Average Language Roi is {highest_avg_roi_language}\nThe Average is {highest_avg_roi_value}')
# Out:
# The Highest Average Language Roi is Persian
# The Average is 27.90536874074074

# %% [markdown]
# # 3. Find out the unique genres of movies in this dataset.

# %%
a=set(imdb['genres'].unique())

# %%
unique_genres=set(genre for sublist in df['genres'].str.split('|').dropna() for genre in sublist)
print(unique_genres)
# Out:
# {'Action', 'Game-Show', 'Thriller', 'Biography', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Family', 'Romance', 'Sport', 'News', 'Sci-Fi', 'Animation', 'Mystery', 'Horror', 'Music', 'War', 'Reality-TV', 'Musical', 'Western', 'Crime', 'Film-Noir', 'History', 'Documentary', 'Short'}

# %% [markdown]
# # 4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
table=imdb[['director_name','movie_title']]

# %% [markdown]
# # 5. Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %%
actors = pd.concat([df['actor_1_name'], df['actor_2_name']])
actor_counts = actors.value_counts()
most_frequent_actor = actor_counts.idxmax()
movies_with_actor = imdb[(imdb['actor_1_name']==most_frequent_actor) | (imdb['actor_2_name']==most_frequent_actor)]
actor_details = {'actor': most_frequent_actor,'movie_count': actor_counts.max(),'movies': movies_with_actor[['movie_title', 'genres', 'profit']]}
actor_details
# Out:
# {'actor': 'Robert De Niro',
#  'movie_count': 54,
#  'movies':                                 movie_title  \
#  293                         Little Fockers
#  518   The Adventures of Rocky & Bullwinkle
#  541                             Shark Tale
#  619                           Killer Elite
#  632                              The Score
#  710                       Meet the Fockers
#  761                                    Joy
#  783                           Analyze That
#  784                         Righteous Kill
#  838                       Meet the Parents
#  868                                  Ronin
#  879                                The Fan
#  920                                 Casino
#  1140                              Sleepers
#  1168                            15 Minutes
#  1209                            The Intern
#  1281                          Mean Streets
#  1285                       City by the Sea
#  1337                          Grudge Match
# ...
